# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
spark = SparkSession.builder.appName('sol').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/ContainsNull.csv</td><td>ContainsNull.csv</td><td>61</td></tr><tr><td>dbfs:/FileStore/tables/Ecommerce_Customers.csv</td><td>Ecommerce_Customers.csv</td><td>86871</td></tr><tr><td>dbfs:/FileStore/tables/Spark_Essentials-5d27c.dbc</td><td>Spark_Essentials-5d27c.dbc</td><td>1414841</td></tr><tr><td>dbfs:/FileStore/tables/appl_stock.csv</td><td>appl_stock.csv</td><td>143130</td></tr><tr><td>dbfs:/FileStore/tables/cogsley_clients.csv</td><td>cogsley_clients.csv</td><td>384219</td></tr><tr><td>dbfs:/FileStore/tables/cogsley_sales.csv</td><td>cogsley_sales.csv</td><td>2176442</td></tr><tr><td>dbfs:/FileStore/tables/cruise_ship_info.csv</td><td>cruise_ship_info.csv</td><td>8734</td></tr><tr><td>dbfs:/FileStore/tables/people.json</td><td>people.json</td><td>73</td></tr><tr><td>dbfs:/FileStore/tables/sales_info.csv</td><td>sales_info.csv</td><td>196</td></tr><tr><td>dbfs:/FileStore/tables/sample_linear_regression_data.txt</td><td>sample_linear_regression_data.txt</td><td>119069</td></tr><tr><td>dbfs:/FileStore/tables/state_info.csv</td><td>state_info.csv</td><td>2778</td></tr><tr><td>dbfs:/FileStore/tables/walmart_stock.csv</td><td>walmart_stock.csv</td><td>90266</td></tr></tbody></table></div>

# %%
path= '/FileStore/tables/cruise_ship_info.csv'
df = spark.read.csv(path,inferSchema= True,header= True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+---+------------------+----------+------+------+-----------------+----+
#   Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
#     Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
#       Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|
# Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|
#    Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|
#     Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+
# only showing top 5 rows
#
# </div>

# %%
df.groupBy('Cruise_line').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-----+
#       Cruise_line|count|
# +-----------------+-----+
#             Costa|   11|
#               P&amp;O|    6|
#            Cunard|    3|
# Regent_Seven_Seas|    5|
#               MSC|    8|
#          Carnival|   22|
#           Crystal|    2|
#            Orient|    1|
#          Princess|   17|
#         Silversea|    4|
#          Seabourn|    3|
#  Holland_American|   14|
#          Windstar|    3|
#            Disney|    2|
#         Norwegian|   13|
#           Oceania|    3|
#           Azamara|    2|
#         Celebrity|   10|
#              Star|    6|
#   Royal_Caribbean|   23|
# +-----------------+-----+
#
# </div>

# %%
from pyspark.ml.feature import StringIndexer
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# we can also create dummy variables by first string indexing and then one hot encoding
indexer = StringIndexer(inputCol='Cruise_line',outputCol='Cruise_line_index')
indexed = indexer.fit(df).transform(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
indexed.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+---+------------------+----------+------+------+-----------------+----+-----------------+
#   Ship_name|Cruise_line|Age|           Tonnage|passengers|length|cabins|passenger_density|crew|Cruise_line_index|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+-----------------+
#     Journey|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|
#       Quest|    Azamara|  6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|
# Celebration|   Carnival| 26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|              1.0|
#    Conquest|   Carnival| 11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|              1.0|
#     Destiny|   Carnival| 17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|              1.0|
#     Ecstasy|   Carnival| 22|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
#     Elation|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
#     Fantasy|   Carnival| 23|            70.367|     20.56|  8.55| 10.22|            34.23| 9.2|              1.0|
# Fascination|   Carnival| 19|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
#     Freedom|   Carnival|  6|110.23899999999999|      37.0|  9.51| 14.87|            29.79|11.5|              1.0|
#       Glory|   Carnival| 10|             110.0|     29.74|  9.51| 14.87|            36.99|11.6|              1.0|
#     Holiday|   Carnival| 28|            46.052|     14.52|  7.27|  7.26|            31.72| 6.6|              1.0|
# Imagination|   Carnival| 18|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
# Inspiration|   Carnival| 17|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
#      Legend|   Carnival| 11|              86.0|     21.24|  9.63| 10.62|            40.49| 9.3|              1.0|
#    Liberty*|   Carnival|  8|             110.0|     29.74|  9.51| 14.87|            36.99|11.6|              1.0|
#     Miracle|   Carnival|  9|              88.5|     21.24|  9.63| 10.62|            41.67|10.3|              1.0|
#    Paradise|   Carnival| 15|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
#       Pride|   Carnival| 12|              88.5|     21.24|  9.63| 11.62|            41.67| 9.3|              1.0|
#   Sensation|   Carnival| 20|            70.367|     20.52|  8.55|  10.2|            34.29| 9.2|              1.0|
# +-----------+-----------+---+------------------+----------+------+------+-----------------+----+-----------------+
# only showing top 20 rows
#
# </div>

# %%
type(indexed)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">12</span><span class="ansired">]: </span>pyspark.sql.dataframe.DataFrame
# </div>

# %%
df.groupBy('Ship_name').count().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------+-----+
#    Ship_name|count|
# +------------+-----+
#        Virgo|    1|
#      Fortuna|    1|
#       Shadow|    1|
#      Empress|    1|
#         Wind|    2|
#     Paradise|    1|
#         Surf|    1|
#       Wonder|    1|
#        Magic|    1|
#     Symphony|    1|
#     Sinfonia|    1|
#  Inspiration|    1|
#    Millenium|    1|
#     Solstice|    1|
# PrideofAloha|    1|
#      Majesty|    2|
#      Ventura|    1|
#    Romantica|    1|
#       Spirit|    4|
#        Oasis|    1|
# +------------+-----+
# only showing top 20 rows
#
# </div>

# %%
df2 = indexed.select(['Age',
 'Tonnage',
 'passengers',
 'length',
 'cabins',
 'passenger_density',
 'crew',
 'Cruise_line_index'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------------------+----------+------+------+-----------------+----+-----------------+
# Age|           Tonnage|passengers|length|cabins|passenger_density|crew|Cruise_line_index|
# +---+------------------+----------+------+------+-----------------+----+-----------------+
#   6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|
#   6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|
# +---+------------------+----------+------+------+-----------------+----+-----------------+
# only showing top 2 rows
#
# </div>

# %%
df2.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------------------+----------+------+------+-----------------+----+-----------------+
# Age|           Tonnage|passengers|length|cabins|passenger_density|crew|Cruise_line_index|
# +---+------------------+----------+------+------+-----------------+----+-----------------+
#   6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|
#   6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|
#  26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|              1.0|
#  11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|              1.0|
#  17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|              1.0|
# +---+------------------+----------+------+------+-----------------+----+-----------------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.ml.linalg import Vectors
from pyspark.ml.feature import VectorAssembler
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assembler =  VectorAssembler(inputCols=['Age','Tonnage','passengers','length','cabins','passenger_density','Cruise_line_index'],
                            outputCol = 'features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output = assembler.transform(df2)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
output.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+------------------+----------+------+------+-----------------+----+-----------------+--------------------+
# Age|           Tonnage|passengers|length|cabins|passenger_density|crew|Cruise_line_index|            features|
# +---+------------------+----------+------+------+-----------------+----+-----------------+--------------------+
#   6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|[6.0,30.276999999...|
#   6|30.276999999999997|      6.94|  5.94|  3.55|            42.64|3.55|             16.0|[6.0,30.276999999...|
#  26|            47.262|     14.86|  7.22|  7.43|             31.8| 6.7|              1.0|[26.0,47.262,14.8...|
#  11|             110.0|     29.74|  9.53| 14.88|            36.99|19.1|              1.0|[11.0,110.0,29.74...|
#  17|           101.353|     26.42|  8.92| 13.21|            38.36|10.0|              1.0|[17.0,101.353,26....|
# +---+------------------+----------+------+------+-----------------+----+-----------------+--------------------+
# only showing top 5 rows
#
# </div>

# %%
final_data = output.select(['features','crew'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
final_data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+----+
#             features|crew|
# +--------------------+----+
# [6.0,30.276999999...|3.55|
# [6.0,30.276999999...|3.55|
# [26.0,47.262,14.8...| 6.7|
# [11.0,110.0,29.74...|19.1|
# [17.0,101.353,26....|10.0|
# +--------------------+----+
# only showing top 5 rows
#
# </div>

# %%
train_data,test_data = final_data.randomSplit([0.7,0.3])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
train_data.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+-----+
#             features| crew|
# +--------------------+-----+
# [4.0,220.0,54.0,1...| 21.0|
# [5.0,86.0,21.04,9...|  8.0|
# [5.0,115.0,35.74,...| 12.2|
# [5.0,122.0,28.5,1...|  6.7|
# [5.0,133.5,39.59,...|13.13|
# +--------------------+-----+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.ml.regression import LinearRegression
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr=LinearRegression(featuresCol='features',labelCol='crew',predictionCol='prediction')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
lr_model = lr.fit(train_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
model_summary = lr_model.summary
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print('p_values: {}'.format(model_summary.pValues) )
print('\n')
print('r2 {}'.format(model_summary.r2) )
print('\n')
print('rmse{}'.format(model_summary.rootMeanSquaredError))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">p_values: [0.2560575733776562, 0.7118975632861002, 0.005401169974018849, 0.006695935210312198, 3.3728575488112256e-13, 0.7498246253536756, 0.09766763491775654, 0.6492834892660388]
#
#
# r2 0.911337721318
#
#
# rmse1.02108451573
# </div>

# %%
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+---------+-----------+------------------+------------------+-----------------+-----------------+------------------+-----------------+-----------------+
# summary|Ship_name|Cruise_line|               Age|           Tonnage|       passengers|           length|            cabins|passenger_density|             crew|
# +-------+---------+-----------+------------------+------------------+-----------------+-----------------+------------------+-----------------+-----------------+
#   count|      158|        158|               158|               158|              158|              158|               158|              158|              158|
#    mean| Infinity|       null|15.689873417721518| 71.28467088607599|18.45740506329114|8.130632911392404| 8.830000000000005|39.90094936708861|7.794177215189873|
#  stddev|      NaN|       null| 7.615691058751413|37.229540025907866|9.677094775143416|1.793473548054825|4.4714172221480615| 8.63921711391542|3.503486564627034|
#     min|Adventure|    Azamara|                 4|             2.329|             0.66|             2.79|              0.33|             17.7|             0.59|
#     max|Zuiderdam|   Windstar|                48|             220.0|             54.0|            11.82|              27.0|            71.43|             21.0|
# +-------+---------+-----------+------------------+------------------+-----------------+-----------------+------------------+-----------------+-----------------+
#
# </div>

# %%
test_result = lr_model.evaluate(test_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(test_result.r2)
print(test_result.rootMeanSquaredError)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">0.959266032908
# 0.724801262883
# </div>

# %%
unlabeled_data = test_data.select('features')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred = lr_model.transform(unlabeled_data)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
pred.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------------+------------------+
#             features|        prediction|
# +--------------------+------------------+
# [6.0,30.276999999...| 4.464043114227439|
# [6.0,90.0,20.0,9....|10.308127815969907|
# [6.0,93.0,23.94,9...|10.734269384561328|
# [6.0,112.0,38.0,9...|11.266200930061606|
# [7.0,158.0,43.7,1...|13.706973833359338|
# +--------------------+------------------+
# only showing top 5 rows
#
# </div>

# %%
from pyspark.sql.functions import corr
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.select(corr('crew','passengers')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------------------+
# corr(crew, passengers)|
# +----------------------+
#     0.9152341306065384|
# +----------------------+
#
# </div>
