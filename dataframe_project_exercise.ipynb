# %%
from pyspark.sql import SparkSession
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#Start a simple Spark Session
spark = SparkSession.builder.appName('ex').getOrCreate()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %fs ls /FileStore/tables
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/ContainsNull.csv</td><td>ContainsNull.csv</td><td>61</td></tr><tr><td>dbfs:/FileStore/tables/Spark_Essentials-5d27c.dbc</td><td>Spark_Essentials-5d27c.dbc</td><td>1414841</td></tr><tr><td>dbfs:/FileStore/tables/appl_stock.csv</td><td>appl_stock.csv</td><td>143130</td></tr><tr><td>dbfs:/FileStore/tables/cogsley_clients.csv</td><td>cogsley_clients.csv</td><td>384219</td></tr><tr><td>dbfs:/FileStore/tables/cogsley_sales.csv</td><td>cogsley_sales.csv</td><td>2176442</td></tr><tr><td>dbfs:/FileStore/tables/people.json</td><td>people.json</td><td>73</td></tr><tr><td>dbfs:/FileStore/tables/sales_info.csv</td><td>sales_info.csv</td><td>196</td></tr><tr><td>dbfs:/FileStore/tables/state_info.csv</td><td>state_info.csv</td><td>2778</td></tr><tr><td>dbfs:/FileStore/tables/walmart_stock.csv</td><td>walmart_stock.csv</td><td>90266</td></tr></tbody></table></div>

# %%
#Load the Walmart Stock CSV File, have Spark infer the data types.
path = 'FileStore/tables/walmart_stock.csv'
df = spark.read.csv(path,inferSchema= True,header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------------+---------+---------+------------------+--------+------------------+
#                Date|              Open|     High|      Low|             Close|  Volume|         Adj Close|
# +-------------------+------------------+---------+---------+------------------+--------+------------------+
# 2012-01-03 00:00:00|         59.970001|61.060001|59.869999|         60.330002|12668800|52.619234999999996|
# 2012-01-04 00:00:00|60.209998999999996|60.349998|59.470001|59.709998999999996| 9593300|         52.078475|
# 2012-01-05 00:00:00|         59.349998|59.619999|58.369999|         59.419998|12768200|         51.825539|
# 2012-01-06 00:00:00|         59.419998|59.450001|58.869999|              59.0| 8069400|          51.45922|
# 2012-01-09 00:00:00|         59.029999|59.549999|58.919998|             59.18| 6679300|51.616215000000004|
# +-------------------+------------------+---------+---------+------------------+--------+------------------+
# only showing top 5 rows
#
# </div>

# %%
#What are the column names?
df.columns
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">11</span><span class="ansired">]: </span>[&apos;Date&apos;, &apos;Open&apos;, &apos;High&apos;, &apos;Low&apos;, &apos;Close&apos;, &apos;Volume&apos;, &apos;Adj Close&apos;]
# </div>

# %%
#What does the Schema look like?
df.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- Date: timestamp (nullable = true)
# -- Open: double (nullable = true)
# -- High: double (nullable = true)
# -- Low: double (nullable = true)
# -- Close: double (nullable = true)
# -- Volume: integer (nullable = true)
# -- Adj Close: double (nullable = true)
#
# </div>

# %%
#Print out the first 5 columns
df.select(['Date', 'Open', 'High', 'Low', 'Close']).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------------+------------------+------------------+------------------+
#                Date|              Open|              High|               Low|             Close|
# +-------------------+------------------+------------------+------------------+------------------+
# 2012-01-03 00:00:00|         59.970001|         61.060001|         59.869999|         60.330002|
# 2012-01-04 00:00:00|60.209998999999996|         60.349998|         59.470001|59.709998999999996|
# 2012-01-05 00:00:00|         59.349998|         59.619999|         58.369999|         59.419998|
# 2012-01-06 00:00:00|         59.419998|         59.450001|         58.869999|              59.0|
# 2012-01-09 00:00:00|         59.029999|         59.549999|         58.919998|             59.18|
# 2012-01-10 00:00:00|             59.43|59.709998999999996|             58.98|59.040001000000004|
# 2012-01-11 00:00:00|         59.060001|         59.529999|59.040001000000004|         59.400002|
# 2012-01-12 00:00:00|59.790001000000004|              60.0|         59.400002|              59.5|
# 2012-01-13 00:00:00|             59.18|59.610001000000004|59.009997999999996|59.540001000000004|
# 2012-01-17 00:00:00|         59.869999|60.110001000000004|             59.52|         59.849998|
# 2012-01-18 00:00:00|59.790001000000004|         60.029999|         59.650002|60.009997999999996|
# 2012-01-19 00:00:00|             59.93|             60.73|             59.75|60.610001000000004|
# 2012-01-20 00:00:00|             60.75|             61.25|         60.669998|61.009997999999996|
# 2012-01-23 00:00:00|         60.810001|             60.98|60.509997999999996|             60.91|
# 2012-01-24 00:00:00|             60.75|              62.0|             60.75|61.389998999999996|
# 2012-01-25 00:00:00|             61.18|61.610001000000004|61.040001000000004|         61.470001|
# 2012-01-26 00:00:00|         61.799999|             61.84|             60.77|         60.970001|
# 2012-01-27 00:00:00|60.860001000000004|         61.119999|60.540001000000004|60.709998999999996|
# 2012-01-30 00:00:00|         60.470001|             61.32|         60.349998|         61.299999|
# 2012-01-31 00:00:00|         61.529999|             61.57|         60.580002|61.360001000000004|
# +-------------------+------------------+------------------+------------------+------------------+
# only showing top 20 rows
#
# </div>

# %%
##Print out the first 5 rows
df.head(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">25</span><span class="ansired">]: </span>
# [Row(Date=datetime.datetime(2012, 1, 3, 0, 0), Open=59.970001, High=61.060001, Low=59.869999, Close=60.330002, Volume=12668800, Adj Close=52.619234999999996),
#  Row(Date=datetime.datetime(2012, 1, 4, 0, 0), Open=60.209998999999996, High=60.349998, Low=59.470001, Close=59.709998999999996, Volume=9593300, Adj Close=52.078475),
#  Row(Date=datetime.datetime(2012, 1, 5, 0, 0), Open=59.349998, High=59.619999, Low=58.369999, Close=59.419998, Volume=12768200, Adj Close=51.825539),
#  Row(Date=datetime.datetime(2012, 1, 6, 0, 0), Open=59.419998, High=59.450001, Low=58.869999, Close=59.0, Volume=8069400, Adj Close=51.45922),
#  Row(Date=datetime.datetime(2012, 1, 9, 0, 0), Open=59.029999, High=59.549999, Low=58.919998, Close=59.18, Volume=6679300, Adj Close=51.616215000000004)]
# </div>

# %%
#Use describe() to learn about the DataFrame.
df.describe().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
# summary|              Open|             High|              Low|            Close|           Volume|        Adj Close|
# +-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
#   count|              1258|             1258|             1258|             1258|             1258|             1258|
#    mean| 72.35785375357709|72.83938807631165| 71.9186009594594|72.38844998012726|8222093.481717011|67.23883848728146|
#  stddev|  6.76809024470826|6.768186808159218|6.744075756255496|6.756859163732991|  4519780.8431556|6.722609449996857|
#     min|56.389998999999996|        57.060001|        56.299999|        56.419998|          2094900|        50.363689|
#     max|         90.800003|        90.970001|            89.25|        90.470001|         80898100|84.91421600000001|
# +-------+------------------+-----------------+-----------------+-----------------+-----------------+-----------------+
#
# </div>

# %%
df.describe().printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- summary: string (nullable = true)
# -- Open: string (nullable = true)
# -- High: string (nullable = true)
# -- Low: string (nullable = true)
# -- Close: string (nullable = true)
# -- Volume: string (nullable = true)
# -- Adj Close: string (nullable = true)
#
# </div>

# %%
from pyspark.sql.functions import format_number
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
des = df.describe()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
des.select(des['summary'],
          format_number(des['Open'].cast('float'),2).alias('Open'),
          format_number(des['High'].cast('float'),2).alias('High'),
          format_number(des['Low'].cast('float'),2).alias('Low'),
          format_number(des['Close'].cast('float'),2).alias('Close'),
          format_number(des['Volume'].cast('float'),2).alias('Volume'),
          format_number(des['Adj Close'].cast('float'),2).alias('Adj Close')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+--------+--------+--------+--------+-------------+---------+
# summary|    Open|    High|     Low|   Close|       Volume|Adj Close|
# +-------+--------+--------+--------+--------+-------------+---------+
#   count|1,258.00|1,258.00|1,258.00|1,258.00|     1,258.00| 1,258.00|
#    mean|   72.36|   72.84|   71.92|   72.39| 8,222,093.50|    67.24|
#  stddev|    6.77|    6.77|    6.74|    6.76| 4,519,781.00|     6.72|
#     min|   56.39|   57.06|   56.30|   56.42| 2,094,900.00|    50.36|
#     max|   90.80|   90.97|   89.25|   90.47|80,898,096.00|    84.91|
# +-------+--------+--------+--------+--------+-------------+---------+
#
# </div>

# %%
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------------+---------+---------+------------------+--------+------------------+
#                Date|              Open|     High|      Low|             Close|  Volume|         Adj Close|
# +-------------------+------------------+---------+---------+------------------+--------+------------------+
# 2012-01-03 00:00:00|         59.970001|61.060001|59.869999|         60.330002|12668800|52.619234999999996|
# 2012-01-04 00:00:00|60.209998999999996|60.349998|59.470001|59.709998999999996| 9593300|         52.078475|
# 2012-01-05 00:00:00|         59.349998|59.619999|58.369999|         59.419998|12768200|         51.825539|
# 2012-01-06 00:00:00|         59.419998|59.450001|58.869999|              59.0| 8069400|          51.45922|
# 2012-01-09 00:00:00|         59.029999|59.549999|58.919998|             59.18| 6679300|51.616215000000004|
# +-------------------+------------------+---------+---------+------------------+--------+------------------+
# only showing top 5 rows
#
# </div>

# %%
#Create a new dataframe with a column called HV Ratio that is the ratio of the High Price versus volume of stock traded for a day
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hv = df.withColumn('HV Ratio',df['Volume']/df['High'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
hv.select('HV Ratio').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+
#           HV Ratio|
# +------------------+
# 207481.16266817617|
#  158961.0657485026|
# 214159.68155249383|
# 135734.22816258657|
# 112162.89021264299|
# 115680.79242473276|
#  106930.9609764986|
# 120606.66666666667|
# 129664.48364931246|
# 141407.41737801666|
#   98474.0979256055|
# 152059.93742795984|
# 169449.79591836734|
#  116990.8166612004|
# 118754.83870967742|
#  96020.12504430895|
#  120249.0297542044|
# 102868.12995530317|
# 124541.74820613177|
#  158543.1216501543|
# +------------------+
# only showing top 20 rows
#
# </div>

# %%
type(hv['HV Ratio'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">63</span><span class="ansired">]: </span>pyspark.sql.column.Column
# </div>

# %%
type(hv.select('HV Ratio'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">67</span><span class="ansired">]: </span>pyspark.sql.dataframe.DataFrame
# </div>

# %%
df.show(5)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+------------------+---------+---------+------------------+--------+------------------+
#                Date|              Open|     High|      Low|             Close|  Volume|         Adj Close|
# +-------------------+------------------+---------+---------+------------------+--------+------------------+
# 2012-01-03 00:00:00|         59.970001|61.060001|59.869999|         60.330002|12668800|52.619234999999996|
# 2012-01-04 00:00:00|60.209998999999996|60.349998|59.470001|59.709998999999996| 9593300|         52.078475|
# 2012-01-05 00:00:00|         59.349998|59.619999|58.369999|         59.419998|12768200|         51.825539|
# 2012-01-06 00:00:00|         59.419998|59.450001|58.869999|              59.0| 8069400|          51.45922|
# 2012-01-09 00:00:00|         59.029999|59.549999|58.919998|             59.18| 6679300|51.616215000000004|
# +-------------------+------------------+---------+---------+------------------+--------+------------------+
# only showing top 5 rows
#
# </div>

# %%
df.orderBy(df['High'].desc()).select(['Date','High']).show(1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+---------+
#                Date|     High|
# +-------------------+---------+
# 2015-01-13 00:00:00|90.970001|
# +-------------------+---------+
# only showing top 1 row
#
# </div>

# %%
#What is the mean of the Close column
from pyspark.sql.functions import avg
df.select(avg('Close')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+
#        avg(Close)|
# +-----------------+
# 72.38844998012726|
# +-----------------+
#
# </div>

# %%
#What is the max and min of the Volume column
from pyspark.sql.functions import max,min
df.select(max('Volume'),min('Volume')).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----------+
# max(Volume)|min(Volume)|
# +-----------+-----------+
#    80898100|    2094900|
# +-----------+-----------+
#
# </div>

# %%
#How many days was the Close lower than 60 dollars
df.filter(df['Close']<60).count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">107</span><span class="ansired">]: </span>81
# </div>

# %%
#What percentage of the time was the High greater than 80 dollars ?
df.filter(df['High']>80).count()*100/df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">118</span><span class="ansired">]: </span>9
# </div>

# %%
#What is the Pearson correlation between High and Volume?
df.corr('High','Volume')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">123</span><span class="ansired">]: </span>-0.3384326061737161
# </div>

# %%
#What is the max High per year?
from pyspark.sql.functions import (dayofmonth,dayofyear,weekofyear, month,
                                   hour,year,format_number,date_format)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_df = df.withColumn('Year',year(df['Date']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
new_df.groupBy('Year').max().select(['Year','max(High)']).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----+---------+
# Year|max(High)|
# +----+---------+
# 2015|90.970001|
# 2013|81.370003|
# 2014|88.089996|
# 2012|77.599998|
# 2016|75.190002|
# +----+---------+
#
# </div>

# %%
# What is the average Close for each Calendar Month
df2 = df.withColumn('Month',month(df['Date']))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df2.groupBy('month').mean().select(['month','avg(Close)']).orderBy('month').show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+-----------------+
# month|       avg(Close)|
# +-----+-----------------+
#     1|71.44801958415842|
#     2|  71.306804443299|
#     3|71.77794377570092|
#     4|72.97361900952382|
#     5|72.30971688679247|
#     6| 72.4953774245283|
#     7|74.43971943925233|
#     8|73.02981855454546|
#     9|72.18411785294116|
#    10|71.57854545454543|
#    11| 72.1110893069307|
#    12|72.84792478301885|
# +-----+-----------------+
#
# </div>
